# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# We are going to use bar charts to understand the trends of different modes of transport in different regions or countries

# %%
df = pd.read_csv('transport_air.csv')

# %%
df
# Out:
#                                       Year  2004  2005  2006  2009  2010  \
# 0                                  America   860   946   963   884   986
# 1        Europe Africa and the Middle East   940  1129  1248  1276  1389
# 2  Australia New Zealand and South Pacific   338   426   457   467   510
# 3                               North Asia   992  1086  1192  1014  1197
# 4                 South and Southeast Asia  1226  1441  1602  1691  2106
# 5                                    China  1500  1563  1901  2150  2744
# 6                                   Taiwan  1128  1184  1232  1120  1224
#
#    2011  2012  2013  2014  2015  2016
# 0  1028  1014   961   988  1034  1081
# 1  1400  1441  1472  1445  1419  1488
# 2   497   487   482   490   475   475
# 3  1259  1285  1191  1315  1334  1491
# 4  2290  2263  2362  2327  2335  2504
# 5  3284  3814  4558  5006  5298  5033
# 6  1235  1213  1250  1214  1201  1238

# %%
# data to plot
n_groups = 7
data_2004 = df['2004']
data_2005 = df['2005']
data_2006 = df['2006']
data_2009 = df['2009']
data_2010 = df['2010']
data_2011 = df['2011']
data_2012 = df['2012']
data_2013 = df['2013']
data_2014 = df['2014']
data_2015 = df['2015']
data_2016 = df['2016']


# create plot
fig, ax = plt.subplots(figsize=(15, 5))
index = np.arange(n_groups)
bar_width = 0.06
opacity = 0.8
   
rects1 = plt.bar(index, data_2004, bar_width,
                 alpha=opacity,
                 color='lightseagreen',
                 label='2004')
 
rects2 = plt.bar(index + bar_width, data_2005, bar_width,
                 alpha=opacity,
                 color='darkcyan',
                 label='2005')

rects3 = plt.bar(index + bar_width + bar_width, data_2006, bar_width,
                 alpha=opacity,
                 color='deepskyblue',
                 label='2006')

rects3 = plt.bar(index + bar_width + bar_width + bar_width, data_2009, bar_width,
                 alpha=opacity,
                 color='slategray',
                 label='2009')

rects4 = plt.bar(index + bar_width + bar_width + bar_width + bar_width, data_2010, bar_width,
                 alpha=opacity,
                 color='royalblue',
                 label='2010')

rects5 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width, data_2011, bar_width,
                 alpha=opacity,
                 color='navy',
                 label='2011')

rects6 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width, data_2012, bar_width,
                 alpha=opacity,
                 color='mediumpurple',
                 label='2012')

rects7 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width, data_2013, bar_width,
                 alpha=opacity,
                 color='darkorchid',
                 label='2013')

rects8 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width, data_2014, bar_width,
                 alpha=opacity,
                 color='plum',
                 label='2014')

rects9 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width, data_2015, bar_width,
                 alpha=opacity,
                 color='m',
                 label='2015')

rects10 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width, data_2016, bar_width,
                 alpha=opacity,
                 color='mediumvioletred',
                 label='2016')

plt.xlabel('Regions/Countries')
plt.ylabel('No. of visitors (in thousands)')
plt.title('No. of Hong Kong Inbound Visitors By Air between 2004 and 2016')
plt.xticks(np.arange(7),('America', 'Europe, Africa and the Middle East', 'Australia, New Zealand and South Pacific', 'North Asia', 'South and Southeast Asia', 'Mainland China', 'Taiwan'), rotation=20)
plt.legend()
plt.minorticks_on()
plt.autoscale(enable=True, axis='both', tight=False)
plt.show()

# %%
df = pd.read_csv('transport_land.csv')

# %%
df
# Out:
#                                       Year  2004  2005   2006   2009   2010  \
# 0                                  America   351   402    440    477    537
# 1        Europe Africa and the Middle East   287   390    440    446    515
# 2  Australia New Zealand and South Pacific    96   132    143    144    157
# 3                               North Asia   432   492    515    435    537
# 4                 South and Southeast Asia   673   754    767    598    702
# 5                                    China  9273  9740  10374  14679  18537
# 6                                   Taiwan   828   823    831    797    824
# 7                                    Macao    30    35     39     47     53
#
#     2011   2012   2013   2014   2015   2016
# 0    554    528    490    480    488    478
# 1    523    501    492    489    478    458
# 2    155    145    134    124    116    109
# 3    548    517    480    479    437    403
# 4    736    680    630    592    557    509
# 5  23074  29193  33920  39919  38566  35906
# 6    781    741    707    667    680    647
# 7     56     56     57     58     58     58

# %%
# data to plot
n_groups = 8
data_2004 = df['2004']
data_2005 = df['2005']
data_2006 = df['2006']
data_2009 = df['2009']
data_2010 = df['2010']
data_2011 = df['2011']
data_2012 = df['2012']
data_2013 = df['2013']
data_2014 = df['2014']
data_2015 = df['2015']
data_2016 = df['2016']


# create plot
fig, ax = plt.subplots(figsize=(15, 5))
index = np.arange(n_groups)
bar_width = 0.06
opacity = 0.8
   
rects1 = plt.bar(index, data_2004, bar_width,
                 alpha=opacity,
                 color='lightseagreen',
                 label='2004')
 
rects2 = plt.bar(index + bar_width, data_2005, bar_width,
                 alpha=opacity,
                 color='darkcyan',
                 label='2005')

rects3 = plt.bar(index + bar_width + bar_width, data_2006, bar_width,
                 alpha=opacity,
                 color='deepskyblue',
                 label='2006')

rects3 = plt.bar(index + bar_width + bar_width + bar_width, data_2009, bar_width,
                 alpha=opacity,
                 color='slategray',
                 label='2009')

rects4 = plt.bar(index + bar_width + bar_width + bar_width + bar_width, data_2010, bar_width,
                 alpha=opacity,
                 color='royalblue',
                 label='2010')

rects5 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width, data_2011, bar_width,
                 alpha=opacity,
                 color='navy',
                 label='2011')

rects6 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width, data_2012, bar_width,
                 alpha=opacity,
                 color='mediumpurple',
                 label='2012')

rects7 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width, data_2013, bar_width,
                 alpha=opacity,
                 color='darkorchid',
                 label='2013')

rects8 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width, data_2014, bar_width,
                 alpha=opacity,
                 color='plum',
                 label='2014')

rects9 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width, data_2015, bar_width,
                 alpha=opacity,
                 color='m',
                 label='2015')

rects10 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width, data_2016, bar_width,
                 alpha=opacity,
                 color='mediumvioletred',
                 label='2016')

plt.xlabel('Region/Countries')
plt.ylabel('No. of visitors (in Thousands)')
plt.title('No. of Hong Kong Inbound Visitors By Land between 2004 and 2016')
plt.xticks(np.arange(8), ('America', 'Europe, Africa and the Middle East', 'Australia, New Zealand and South Pacific', 'North Asia', 'South and Southeast Asia', 'Mainland China', 'Taiwan', 'Macao'), rotation=20)
plt.legend()
plt.minorticks_on()
plt.autoscale(enable=True, axis='both', tight=None)
plt.show()

# %%
df = pd.read_csv('transport_sea.csv')

# %%
df
# Out:
#                                       Year  2004  2005  2006  2009  2010  \
# 0                                  America   189   217   227   207   226
# 1        Europe Africa and the Middle East   153   206   229   247   270
# 2  Australia New Zealand and South Pacific    49    62    68    97   101
# 3                               North Asia   241   275   322   374   474
# 4                 South and Southeast Asia   179   219   291   596   693
# 5                                    China  1473  1238  1317  1128  1404
# 6                                   Taiwan   119   124   115    93   117
# 7                                    Macao   425   446   508   601   697
#
#    2011  2012  2013  2014  2015  2016
# 0   239   236   214   211   206   215
# 1   272   287   289   284   270   281
# 2   106   109   102   101    91   101
# 3   498   531   470   537   521   591
# 4   725   709   726   696   667   688
# 5  1742  1904  2267  2322  1979  1839
# 6   133   134   143   151   135   126
# 7   754   784   846   880   887   848

# %%
# data to plot
n_groups = 8
data_2004 = df['2004']
data_2005 = df['2005']
data_2006 = df['2006']
data_2009 = df['2009']
data_2010 = df['2010']
data_2011 = df['2011']
data_2012 = df['2012']
data_2013 = df['2013']
data_2014 = df['2014']
data_2015 = df['2015']
data_2016 = df['2016']


# create plot
fig, ax = plt.subplots(figsize=(15, 5))
index = np.arange(n_groups)
bar_width = 0.06
opacity = 0.8
   
rects1 = plt.bar(index, data_2004, bar_width,
                 alpha=opacity,
                 color='lightseagreen',
                 label='2004')
 
rects2 = plt.bar(index + bar_width, data_2005, bar_width,
                 alpha=opacity,
                 color='darkcyan',
                 label='2005')

rects3 = plt.bar(index + bar_width + bar_width, data_2006, bar_width,
                 alpha=opacity,
                 color='deepskyblue',
                 label='2006')

rects3 = plt.bar(index + bar_width + bar_width + bar_width, data_2009, bar_width,
                 alpha=opacity,
                 color='slategray',
                 label='2009')

rects4 = plt.bar(index + bar_width + bar_width + bar_width + bar_width, data_2010, bar_width,
                 alpha=opacity,
                 color='royalblue',
                 label='2010')

rects5 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width, data_2011, bar_width,
                 alpha=opacity,
                 color='navy',
                 label='2011')

rects6 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width, data_2012, bar_width,
                 alpha=opacity,
                 color='mediumpurple',
                 label='2012')

rects7 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width, data_2013, bar_width,
                 alpha=opacity,
                 color='darkorchid',
                 label='2013')

rects8 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width, data_2014, bar_width,
                 alpha=opacity,
                 color='plum',
                 label='2014')

rects9 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width, data_2015, bar_width,
                 alpha=opacity,
                 color='m',
                 label='2015')

rects10 = plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width + bar_width, data_2016, bar_width,
                 alpha=opacity,
                 color='mediumvioletred',
                 label='2016')

plt.xlabel('Region')
plt.ylabel('No. of visitors (in thousands)')
plt.title('No. of Hong Kong Inbound Visitors By Sea between 2004 and 2016')
plt.xticks(np.arange(8), ('America', 'Europe, Africa & the Middle East', 'Australia, New Zealand & South Pacific', 'North Asia', 'South & Southeast Asia', 'Mainland China', 'Taiwan', 'Macau'), rotation=20)
plt.legend()
plt.minorticks_on()
plt.autoscale(enable=True, axis='both', tight=False)
plt.show()

# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\josephine wong\appdata\local\programs\python\python36\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\josephine wong\appdata\local\programs\python\python36\lib\site-packages (from sklearn) (0.19.1)

# %% [markdown]
# We are going to use stacked area graphs to compare different modes of transport by HK inbound visitors in long haul markets, short haul markets and mainland China respectively.

# %%
df_long = pd.read_csv('long_haul_market.csv')

# %%
df_long
# Out:
#     Year  By air  By land  By sea
# 0   2004    2138      734     238
# 1   2005    2501      924     279
# 2   2006    2668     1023     295
# 3   2009    2627     1067     304
# 4   2010    2885     1209     327
# 5   2011    2925     1232     345
# 6   2012    2942     1174     345
# 7   2013    2915     1116     316
# 8   2014    2923     1093     312
# 9   2015    2928     1082     567
# 10  2016    3044     1045     597
# 11  2017    3105     1073     573

# %%
df_long = df_long.set_index('Year')
df_long.plot(kind='area', stacked=False, figsize=(10,5))
plt.ylabel('No. of visitors in thousands')
plt.xlabel('Year')
plt.xticks(np.arange(2004,2018, step=1))
plt.title('Mode of Transport of Hong Kong Inbound Visitors (Long Haul Markets)')
# Out:
# Text(0.5,1,'Mode of Transport of Hong Kong Inbound Visitors (Long Haul Markets)')

# %%
df_short = pd.read_csv('short_haul_market.csv')

# %%
df_short
# Out:
#     Year  By air  By land  By sea
# 0   2004    3375     1963     964
# 1   2005    3740     2104    1064
# 2   2006    4057     2152    1236
# 3   2009    3848     1877    1664
# 4   2010    4557     2116    1981
# 5   2011    4818     2121    2110
# 6   2012    4804     1994    2158
# 7   2013    4858     1874    2185
# 8   2014    4920     1796    2264
# 9   2015    4947     1732    2210
# 10  2016    5322     1617    2253
# 11  2017    5496     1678    2352

# %%
df_short = df_short.set_index('Year')
df_short.plot(kind='area', stacked=False, figsize=(10,5))
plt.ylabel('No. of visitors in thousands')
plt.xlabel('Year')
plt.xticks(np.arange(2004,2018, step=1))
plt.title('Mode of Transport of Hong Kong Inbound Visitors (Short Haul Markets excluding Mainland China)')
# Out:
# Text(0.5,1,'Mode of Transport of Hong Kong Inbound Visitors (Short Haul Markets excluding Mainland China)')

# %%
df_mainland = pd.read_csv('mainland.csv')

# %%
df_mainland = df_mainland.set_index('Year')
df_mainland.plot(kind='area', stacked=False, figsize=(10,5))
plt.ylabel('No. of visitors in thousands')
plt.xlabel('Year')
plt.xticks(np.arange(2004,2018, step=1))
plt.title('Mode of Transport of Hong Kong Inbound Visitors (Mainland China)')
# Out:
# Text(0.5,1,'Mode of Transport of Hong Kong Inbound Visitors (Mainland China)')

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, projection='3d')

x1 = df_short['By land'] 
y1 = df_short['By air']
z1 = df_short['By sea']

x2 = df_long['By land'] 
y2 = df_long['By air']
z2 = df_long['By sea']

x3 = df_mainland['By land'] 
y3 = df_mainland['By air']
z3 = df_mainland['By sea']

ax.scatter(x1, y1, z1, s=100,depthshade=True, marker='o')
ax.scatter(x2, y2, z2, s=100,depthshade=True, marker='s')
ax.scatter(x3, y3, z3, s=100,depthshade=True, marker='^')

ax.set_xlabel('By land')
ax.set_ylabel('By air')
ax.set_zlabel('By sea')

plt.show()
